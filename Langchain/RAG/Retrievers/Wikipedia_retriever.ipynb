# %%
# !pip3 install langchain chromadb faiss-cpu tiktoken langchain_huggingface langchain-community wikipedia
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 2.9 MB/s  0:00:01 eta 0:00:01
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11756 sha256=8e193b3f2af22cf27afebacf407d1099a45efd7b907b483ce08c0e3d1433d9cc
#   Stored in directory: /Users/janvi/Library/Caches/pip/wheels/30/24/d3/9d46daa49494cef2f32dc9a8f203aac1f10cec980adba03d1f
# Successfully built wikipedia
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [wikipedia]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.14/bin/python3.14 -m pip install --upgrade pip

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
import wikipedia
wikipedia.set_user_agent("MyApp/1.0") # Set a generic User-Agent name
retriever=WikipediaRetriever(top_k_results=2,lang='en')

# %%
query='who were the empires of india'
docs=retriever.invoke(query)

# %%
for i,doc in enumerate(docs):
    print(f'/n ---Result {i+1}---')
    print(f"Content /n {doc.page_content} ......")
# Out:
# /n ---Result 1---
# Content /n Several empires in human history have been contenders for the largest of all time, depending on definition and mode of measurement. Possible ways of measuring size include area, population, economy, and power. Of these, area is the most commonly used because it has a relatively precise definition and can be feasibly measured with some degree of accuracy; nevertheless, even area is limited in this regard because of the difficulty in defining the boundaries of empires due to things like the indirect nature of imperial control and sparsely inhabited or even uninhabited areas that may nominally have been controlled by an empire but not meaningfully ruled by it.
# ...
